# %% [markdown]
# <a href="https://colab.research.google.com/github/TrungTan369/Machine-Learning-Assignment/blob/main/Bai3_ImageData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/TrungTan369/Machine-Learning-Assignment.git
# Out:
# Cloning into 'Machine-Learning-Assignment'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 9 (delta 0), reused 6 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (9/9), done.

# %%
import sys
sys.path.append('/content/Machine-Learning-Assignment') # Khai báo đường dẫn để Colab hiểu

from modules.data_utils import clean_tabular_data
df = clean_tabular_data(raw_data)
# Out:
# Hello World
